# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/monkeypox-skin-lesion-dataset/Monkeypox_Dataset_metadata.csv
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_04_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_02_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M53_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_03_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M17_02_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M26_02_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M34_02_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Monkeypox/M50_03_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_02_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_02_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM53_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM22_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM82_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM18_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM21_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM103_02_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM69_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM33_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM08_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM57_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM47_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM75_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Val/Others/NM56_02_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M40_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M45_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M40_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M23_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M38_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M43_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M40_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M04_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M39_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M19_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M51_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M48_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M48_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M51_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M38_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M43_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M19_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M39_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M48_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Monkeypox/M43_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM58_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM54_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM71_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM101_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM19_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM54_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM80_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM31_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM101_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM12_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM10_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM36_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM52_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM35_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM14_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM23_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM67_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM17_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM58_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM85_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM72_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM41_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM41_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM79_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Test/Others/NM02_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M25_02_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M42_02_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M33_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M16_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M31_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M21_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M28_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M11_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M29_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M32_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M16_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M44_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M05_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M36_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M49_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M49_02_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M28_03_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M27_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M32_02_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M42_02_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M06_02_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M49_03_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M52_01_00.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M41_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M08_01_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M06_02_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M01_03_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M52_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M54_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M21_01_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M15_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M35_02_09.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M03_01_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M28_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M02_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M42_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M13_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M29_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M21_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M18_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M24_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M36_01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M33_02_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M02_02_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M30_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M55_01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M46_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M15_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M10_02_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M44_01_13.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M46_02_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M28_03_12.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M49_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M10_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M30_02_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M29_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M22_01_06.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M09_03_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M22_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M12_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M37_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M20_02_07.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M36_01_10.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M20_02_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M54_01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M06_01_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M44_01_05.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M33_01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M16_01_08.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M31_02_11.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M25_02_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Fold1/Fold1/Fold1/Train/Monkeypox/M47_01_11.jpg
# ...
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM83_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM47_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM65_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM06_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM36_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM64_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM55_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM56_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM45_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM99_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM84_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM32_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM15_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM39_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM62_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM04_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM45_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM52_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM43_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM30_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM35_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM49_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM56_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM109_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM14_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM87_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM21_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM11_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM104_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM23_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM67_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM81_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM98_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM17_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM28_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM61_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM58_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM57_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM74_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM66_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM27_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM48_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM96_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM85_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM106_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM91_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM72_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM38_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM103_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM41_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM46_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM43_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM24_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM03_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM60_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM41_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM79_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM02_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM99_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM91_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM07_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM43_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Others/NM08_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M17_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M40_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M34_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M31_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M47_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M54_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M07_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M11_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M45_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M26_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M50_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M40_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M35_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M21_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M23_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M34_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M38_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M28_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M09_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M50_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M22_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M21_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M03_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M05_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M32_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M10_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M26_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M41_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M15_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M46_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M43_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M49_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M53_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M01_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M33_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M34_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M40_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M44_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M32_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M16_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M04_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M39_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M32_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M28_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M28_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M19_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M50_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M25_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M24_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M01_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M25_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M35_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M18_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M01_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M37_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M12_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M51_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M29_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M05_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M48_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M46_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M20_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M09_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M31_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M48_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M06_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M42_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M13_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M14_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M29_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M10_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M30_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M08_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M42_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M01_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M24_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M27_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M09_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M51_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M02_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M09_04.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M18_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M30_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M38_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M06_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M02_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M52_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M20_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M34_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M32_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M43_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M19_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M39_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M48_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M43_03.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M49_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M28_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M33_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M49_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M36_01.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M17_02.jpg
# /kaggle/input/monkeypox-skin-lesion-dataset/Original Images/Original Images/Monkey Pox/M55_01.jpg

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torchvision import transforms
from torch.utils.data import DataLoader, random_split, Subset, TensorDataset
from transformers import ViTModel
import os
from sklearn.model_selection import KFold
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import numpy as np
import cv2

# Paths and parameters
folder_path = "/kaggle/input/monkeypox-skin-lesion-dataset/Augmented Images/Augmented Images"
subfolders = ['Monkeypox_augmented', 'Others_augmented']
image_size = (224, 224)
batch_size = 16
epochs = 30
learning_rate = 0.0001
gamma = 0.5  # Weight for combining deep and broad features

# Image transformations
transform = transforms.Compose([
    transforms.Resize(image_size),
    transforms.ToTensor(),
    transforms.Normalize(mean=[0.5, 0.5, 0.5], std=[0.5, 0.5, 0.5])
])

# Load dataset
data = []
labels = []
label_map = {subfolder: idx for idx, subfolder in enumerate(subfolders)}

for subfolder in subfolders:
    subfolder_path = os.path.join(folder_path, subfolder)
    for filename in os.listdir(subfolder_path):
        img_path = os.path.join(subfolder_path, filename)
        img = cv2.imread(img_path)
        if img is not None:
            img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
            img = cv2.resize(img, image_size)
            data.append(img)
            labels.append(label_map[subfolder])

data = np.array(data).astype("float32")
labels = np.array(labels)

# Create PyTorch datasets
data = torch.tensor(data).permute(0, 3, 1, 2) / 255.0  # Normalize
labels = torch.tensor(labels)

# Create a TensorDataset
dataset = TensorDataset(data, labels)

# Define device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# Broad Attention Mechanism
class BroadAttention(nn.Module):
    def __init__(self, hidden_size, num_layers):
        super(BroadAttention, self).__init__()
        self.hidden_size = hidden_size
        self.num_layers = num_layers
        self.attention = nn.MultiheadAttention(embed_dim=hidden_size, num_heads=8)
        self.pool = nn.AdaptiveAvgPool1d(1)

    def forward(self, queries, keys, values):
        # Concatenate all layers' outputs
        queries = torch.cat(queries, dim=1)
        keys = torch.cat(keys, dim=1)
        values = torch.cat(values, dim=1)

        # Apply self-attention
        attention_output, _ = self.attention(queries, keys, values)

        # Pooling
        pooled_output = self.pool(attention_output.permute(0, 2, 1)).squeeze(-1)
        return pooled_output

# Define B2VIT Model
class B2VITNet(nn.Module):
    def __init__(self, vit_model_name, num_classes, gamma=0.5):
        super(B2VITNet, self).__init__()
        self.vit = ViTModel.from_pretrained(vit_model_name, output_attentions=True)
        self.hidden_size = self.vit.config.hidden_size
        self.num_layers = len(self.vit.encoder.layer)
        self.gamma = gamma

        # Broad Attention Level 1
        self.broad_attention_1 = BroadAttention(hidden_size=self.hidden_size, num_layers=self.num_layers)

        # Refinement Layer (Broad Attention Level 2)
        self.refinement_attention = nn.MultiheadAttention(embed_dim=self.hidden_size, num_heads=8)

        # Classifier
        self.classifier = nn.Sequential(
            nn.Linear(self.hidden_size, 512),
            nn.ReLU(),
            nn.Dropout(0.5),
            nn.Linear(512, num_classes)
        )

    def forward(self, pixel_values):
        outputs = self.vit(pixel_values, output_hidden_states=True)
        hidden_states = outputs.hidden_states

        # Deep Features from the last CLS token
        deep_features = hidden_states[-1][:, 0, :]  # CLS token of the last layer

        # Broad Features Level 1
        queries = [layer[:, 0, :].unsqueeze(1) for layer in hidden_states]
        broad_features_1 = self.broad_attention_1(queries, queries, queries)

        # Refinement using attention
        broad_features_1 = broad_features_1.unsqueeze(1).permute(1, 0, 2)  # Prepare for MultiheadAttention
        refined_features, _ = self.refinement_attention(broad_features_1, broad_features_1, broad_features_1)
        refined_features = refined_features.permute(1, 0, 2).squeeze(1)

        # Combine Deep and Refined Broad Features
        combined_features = deep_features + self.gamma * refined_features

        # Classification
        logits = self.classifier(combined_features)
        return logits

# Training function
def train_model(model, train_loader, val_loader, criterion, optimizer, epochs):
    for epoch in range(epochs):
        model.train()
        train_loss = 0.0
        train_preds, train_targets = [], []

        for images, labels in train_loader:
            images, labels = images.to(device), labels.to(device)
            optimizer.zero_grad()
            outputs = model(images)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            train_loss += loss.item() * images.size(0)
            train_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
            train_targets.extend(labels.cpu().numpy())

        train_loss /= len(train_loader.dataset)
        train_accuracy = accuracy_score(train_targets, train_preds)

        model.eval()
        val_loss = 0.0
        val_preds, val_targets = [], []

        with torch.no_grad():
            for images, labels in val_loader:
                images, labels = images.to(device), labels.to(device)
                outputs = model(images)
                loss = criterion(outputs, labels)
                val_loss += loss.item() * images.size(0)
                val_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
                val_targets.extend(labels.cpu().numpy())

        val_loss /= len(val_loader.dataset)
        val_accuracy = accuracy_score(val_targets, val_preds)

        print(f"Epoch {epoch + 1}/{epochs}: Train Loss: {train_loss:.4f}, Train Accuracy: {train_accuracy:.4f}, Val Loss: {val_loss:.4f}, Val Accuracy: {val_accuracy:.4f}")

# Evaluation function
def evaluate_model(model, test_loader):
    model.eval()
    test_preds, test_targets = [], []

    with torch.no_grad():
        for images, labels in test_loader:
            images, labels = images.to(device), labels.to(device)
            outputs = model(images)
            test_preds.extend(torch.argmax(outputs, dim=1).cpu().numpy())
            test_targets.extend(labels.cpu().numpy())

    precision = precision_score(test_targets, test_preds, average='weighted')
    recall = recall_score(test_targets, test_preds, average='weighted')
    f1 = f1_score(test_targets, test_preds, average='weighted')
    accuracy = accuracy_score(test_targets, test_preds)

    return accuracy, precision, recall, f1

# 5-Fold Cross-Validation
kf = KFold(n_splits=5, shuffle=True, random_state=42)
fold_results = []

for fold, (train_indices, val_indices) in enumerate(kf.split(dataset)):
    print(f"\nFold {fold + 1}")
    train_subset = Subset(dataset, train_indices)
    val_subset = Subset(dataset, val_indices)

    train_loader = DataLoader(train_subset, batch_size=batch_size, shuffle=True)
    val_loader = DataLoader(val_subset, batch_size=batch_size, shuffle=False)

    model = B2VITNet("google/vit-base-patch16-224-in21k", num_classes=2, gamma=gamma).to(device)
    criterion = nn.CrossEntropyLoss()
    optimizer = optim.Adam(model.parameters(), lr=learning_rate)

    train_model(model, train_loader, val_loader, criterion, optimizer, epochs)

    accuracy, precision, recall, f1 = evaluate_model(model, val_loader)
    print(f"Fold {fold + 1} - Accuracy: {accuracy:.4f}, Precision: {precision:.4f}, Recall: {recall:.4f}, F1 Score: {f1:.4f}")
    fold_results.append((accuracy, precision, recall, f1))

# Average Results
average_results = np.mean(fold_results, axis=0)
print("\n5-Fold Cross-Validation Results:")
print(f"Average Accuracy: {average_results[0]:.4f}")
print(f"Average Precision: {average_results[1]:.4f}")
print(f"Average Recall: {average_results[2]:.4f}")
print(f"Average F1 Score: {average_results[3]:.4f}")
# Out:
# Fold 1
# config.json:   0%|          | 0.00/502 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/346M [00:00<?, ?B/s]
# Epoch 1/30: Train Loss: 0.3734, Train Accuracy: 0.8465, Val Loss: 0.1599, Val Accuracy: 0.9343
# Epoch 2/30: Train Loss: 0.1315, Train Accuracy: 0.9565, Val Loss: 0.0787, Val Accuracy: 0.9750
# Epoch 3/30: Train Loss: 0.0641, Train Accuracy: 0.9839, Val Loss: 0.1010, Val Accuracy: 0.9687
# Epoch 4/30: Train Loss: 0.0424, Train Accuracy: 0.9875, Val Loss: 0.0364, Val Accuracy: 0.9890
# Epoch 5/30: Train Loss: 0.0200, Train Accuracy: 0.9937, Val Loss: 0.0344, Val Accuracy: 0.9922
# Epoch 6/30: Train Loss: 0.0355, Train Accuracy: 0.9902, Val Loss: 0.0341, Val Accuracy: 0.9922
# Epoch 8/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0254, Val Accuracy: 0.9969
# Epoch 9/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0260, Val Accuracy: 0.9969
# Epoch 10/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0279, Val Accuracy: 0.9969
# Epoch 11/30: Train Loss: 0.0122, Train Accuracy: 0.9965, Val Loss: 0.1726, Val Accuracy: 0.9562
# Epoch 12/30: Train Loss: 0.1061, Train Accuracy: 0.9694, Val Loss: 0.9833, Val Accuracy: 0.7997
# Epoch 13/30: Train Loss: 0.0634, Train Accuracy: 0.9773, Val Loss: 0.0839, Val Accuracy: 0.9844
# Epoch 14/30: Train Loss: 0.0442, Train Accuracy: 0.9863, Val Loss: 0.0701, Val Accuracy: 0.9750
# Epoch 15/30: Train Loss: 0.0286, Train Accuracy: 0.9902, Val Loss: 0.0485, Val Accuracy: 0.9828
# Epoch 16/30: Train Loss: 0.0286, Train Accuracy: 0.9929, Val Loss: 0.0549, Val Accuracy: 0.9890
# Epoch 17/30: Train Loss: 0.0006, Train Accuracy: 0.9996, Val Loss: 0.0519, Val Accuracy: 0.9875
# Epoch 18/30: Train Loss: 0.0180, Train Accuracy: 0.9953, Val Loss: 0.0886, Val Accuracy: 0.9828
# Epoch 19/30: Train Loss: 0.0006, Train Accuracy: 0.9996, Val Loss: 0.0705, Val Accuracy: 0.9890
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0668, Val Accuracy: 0.9890
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0631, Val Accuracy: 0.9890
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0619, Val Accuracy: 0.9890
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0615, Val Accuracy: 0.9890
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0609, Val Accuracy: 0.9890
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0590, Val Accuracy: 0.9906
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0584, Val Accuracy: 0.9906
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0586, Val Accuracy: 0.9906
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0579, Val Accuracy: 0.9906
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0585, Val Accuracy: 0.9906
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0588, Val Accuracy: 0.9906
# Fold 1 - Accuracy: 0.9906, Precision: 0.9908, Recall: 0.9906, F1 Score: 0.9906
#
# Fold 2
# Epoch 1/30: Train Loss: 0.3740, Train Accuracy: 0.8461, Val Loss: 0.1735, Val Accuracy: 0.9358
# Epoch 2/30: Train Loss: 0.0892, Train Accuracy: 0.9702, Val Loss: 0.0833, Val Accuracy: 0.9687
# Epoch 3/30: Train Loss: 0.0662, Train Accuracy: 0.9765, Val Loss: 0.0813, Val Accuracy: 0.9750
# Epoch 4/30: Train Loss: 0.0541, Train Accuracy: 0.9808, Val Loss: 0.1182, Val Accuracy: 0.9640
# Epoch 5/30: Train Loss: 0.0024, Train Accuracy: 0.9992, Val Loss: 0.0476, Val Accuracy: 0.9922
# Epoch 6/30: Train Loss: 0.0003, Train Accuracy: 1.0000, Val Loss: 0.0421, Val Accuracy: 0.9922
# Epoch 7/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0418, Val Accuracy: 0.9937
# Epoch 8/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0446, Val Accuracy: 0.9922
# Epoch 9/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0450, Val Accuracy: 0.9922
# Epoch 10/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0461, Val Accuracy: 0.9922
# Epoch 11/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0466, Val Accuracy: 0.9922
# Epoch 12/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0472, Val Accuracy: 0.9922
# Epoch 13/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0491, Val Accuracy: 0.9922
# Epoch 14/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0494, Val Accuracy: 0.9922
# Epoch 15/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0454, Val Accuracy: 0.9906
# Epoch 16/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0459, Val Accuracy: 0.9922
# Epoch 17/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0465, Val Accuracy: 0.9922
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0474, Val Accuracy: 0.9922
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0480, Val Accuracy: 0.9922
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0486, Val Accuracy: 0.9922
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0491, Val Accuracy: 0.9922
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0498, Val Accuracy: 0.9922
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0499, Val Accuracy: 0.9922
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0503, Val Accuracy: 0.9922
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0511, Val Accuracy: 0.9922
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0513, Val Accuracy: 0.9922
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0519, Val Accuracy: 0.9922
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0525, Val Accuracy: 0.9922
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0531, Val Accuracy: 0.9937
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0534, Val Accuracy: 0.9937
# Fold 2 - Accuracy: 0.9937, Precision: 0.9938, Recall: 0.9937, F1 Score: 0.9937
#
# Fold 3
# Epoch 1/30: Train Loss: 0.4282, Train Accuracy: 0.8187, Val Loss: 0.1179, Val Accuracy: 0.9514
# Epoch 2/30: Train Loss: 0.1266, Train Accuracy: 0.9554, Val Loss: 0.0625, Val Accuracy: 0.9812
# Epoch 3/30: Train Loss: 0.0381, Train Accuracy: 0.9875, Val Loss: 0.0639, Val Accuracy: 0.9765
# Epoch 4/30: Train Loss: 0.0430, Train Accuracy: 0.9851, Val Loss: 0.0580, Val Accuracy: 0.9812
# Epoch 5/30: Train Loss: 0.0248, Train Accuracy: 0.9918, Val Loss: 0.1265, Val Accuracy: 0.9514
# Epoch 6/30: Train Loss: 0.0190, Train Accuracy: 0.9937, Val Loss: 0.0422, Val Accuracy: 0.9890
# Epoch 7/30: Train Loss: 0.0010, Train Accuracy: 0.9996, Val Loss: 0.0317, Val Accuracy: 0.9953
# Epoch 8/30: Train Loss: 0.0001, Train Accuracy: 1.0000, Val Loss: 0.0283, Val Accuracy: 0.9953
# Epoch 9/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0294, Val Accuracy: 0.9953
# Epoch 10/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0303, Val Accuracy: 0.9953
# Epoch 11/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0312, Val Accuracy: 0.9953
# Epoch 12/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0315, Val Accuracy: 0.9953
# Epoch 13/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0317, Val Accuracy: 0.9953
# Epoch 14/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0323, Val Accuracy: 0.9953
# Epoch 15/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0326, Val Accuracy: 0.9953
# Epoch 16/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0328, Val Accuracy: 0.9953
# Epoch 17/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0328, Val Accuracy: 0.9953
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0324, Val Accuracy: 0.9953
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0330, Val Accuracy: 0.9953
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0331, Val Accuracy: 0.9953
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0335, Val Accuracy: 0.9953
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0335, Val Accuracy: 0.9953
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0335, Val Accuracy: 0.9953
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0344, Val Accuracy: 0.9953
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0349, Val Accuracy: 0.9953
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0352, Val Accuracy: 0.9953
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0355, Val Accuracy: 0.9953
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0356, Val Accuracy: 0.9953
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0358, Val Accuracy: 0.9953
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0358, Val Accuracy: 0.9953
# Fold 3 - Accuracy: 0.9953, Precision: 0.9953, Recall: 0.9953, F1 Score: 0.9953
#
# Fold 4
# Epoch 1/30: Train Loss: 0.3318, Train Accuracy: 0.8653, Val Loss: 0.2130, Val Accuracy: 0.9263
# Epoch 2/30: Train Loss: 0.1001, Train Accuracy: 0.9675, Val Loss: 0.2152, Val Accuracy: 0.9232
# Epoch 3/30: Train Loss: 0.0755, Train Accuracy: 0.9726, Val Loss: 0.2412, Val Accuracy: 0.9248
# Epoch 4/30: Train Loss: 0.0284, Train Accuracy: 0.9910, Val Loss: 0.0230, Val Accuracy: 0.9906
# Epoch 5/30: Train Loss: 0.0291, Train Accuracy: 0.9922, Val Loss: 0.0472, Val Accuracy: 0.9890
# Epoch 6/30: Train Loss: 0.0140, Train Accuracy: 0.9945, Val Loss: 0.0956, Val Accuracy: 0.9734
# Epoch 7/30: Train Loss: 0.0403, Train Accuracy: 0.9855, Val Loss: 0.0939, Val Accuracy: 0.9687
# Epoch 8/30: Train Loss: 0.0426, Train Accuracy: 0.9883, Val Loss: 0.0136, Val Accuracy: 0.9969
# Epoch 9/30: Train Loss: 0.0324, Train Accuracy: 0.9875, Val Loss: 0.1358, Val Accuracy: 0.9624
# Epoch 10/30: Train Loss: 0.0229, Train Accuracy: 0.9941, Val Loss: 0.1099, Val Accuracy: 0.9702
# Epoch 11/30: Train Loss: 0.0014, Train Accuracy: 0.9992, Val Loss: 0.0329, Val Accuracy: 0.9890
# Epoch 12/30: Train Loss: 0.0002, Train Accuracy: 1.0000, Val Loss: 0.0225, Val Accuracy: 0.9922
# Epoch 13/30: Train Loss: 0.0001, Train Accuracy: 1.0000, Val Loss: 0.0282, Val Accuracy: 0.9906
# Epoch 14/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0275, Val Accuracy: 0.9906
# Epoch 15/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0287, Val Accuracy: 0.9906
# Epoch 16/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0316, Val Accuracy: 0.9906
# Epoch 17/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0332, Val Accuracy: 0.9906
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0341, Val Accuracy: 0.9906
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0355, Val Accuracy: 0.9906
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0359, Val Accuracy: 0.9906
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0366, Val Accuracy: 0.9906
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0373, Val Accuracy: 0.9906
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0379, Val Accuracy: 0.9906
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0388, Val Accuracy: 0.9906
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0403, Val Accuracy: 0.9906
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0410, Val Accuracy: 0.9906
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0404, Val Accuracy: 0.9906
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0403, Val Accuracy: 0.9906
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0409, Val Accuracy: 0.9906
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0405, Val Accuracy: 0.9906
# Fold 4 - Accuracy: 0.9906, Precision: 0.9908, Recall: 0.9906, F1 Score: 0.9906
#
# Fold 5
# Epoch 1/30: Train Loss: 0.3752, Train Accuracy: 0.8618, Val Loss: 0.1162, Val Accuracy: 0.9498
# Epoch 2/30: Train Loss: 0.1054, Train Accuracy: 0.9616, Val Loss: 0.0408, Val Accuracy: 0.9781
# Epoch 3/30: Train Loss: 0.1007, Train Accuracy: 0.9663, Val Loss: 0.0367, Val Accuracy: 0.9828
# Epoch 4/30: Train Loss: 0.0294, Train Accuracy: 0.9898, Val Loss: 0.0765, Val Accuracy: 0.9765
# Epoch 5/30: Train Loss: 0.0126, Train Accuracy: 0.9961, Val Loss: 0.0259, Val Accuracy: 0.9937
# Epoch 6/30: Train Loss: 0.0554, Train Accuracy: 0.9847, Val Loss: 0.0706, Val Accuracy: 0.9781
# Epoch 7/30: Train Loss: 0.0246, Train Accuracy: 0.9930, Val Loss: 0.0613, Val Accuracy: 0.9781
# Epoch 8/30: Train Loss: 0.0044, Train Accuracy: 0.9980, Val Loss: 0.0450, Val Accuracy: 0.9859
# Epoch 9/30: Train Loss: 0.0227, Train Accuracy: 0.9945, Val Loss: 0.0389, Val Accuracy: 0.9875
# Epoch 10/30: Train Loss: 0.0226, Train Accuracy: 0.9945, Val Loss: 0.0474, Val Accuracy: 0.9875
# Epoch 11/30: Train Loss: 0.0478, Train Accuracy: 0.9832, Val Loss: 0.2878, Val Accuracy: 0.8856
# Epoch 12/30: Train Loss: 0.0579, Train Accuracy: 0.9820, Val Loss: 0.3039, Val Accuracy: 0.8636
# Epoch 13/30: Train Loss: 0.0230, Train Accuracy: 0.9910, Val Loss: 0.0772, Val Accuracy: 0.9812
# Epoch 14/30: Train Loss: 0.0018, Train Accuracy: 0.9992, Val Loss: 0.0303, Val Accuracy: 0.9875
# Epoch 15/30: Train Loss: 0.0001, Train Accuracy: 1.0000, Val Loss: 0.0228, Val Accuracy: 0.9890
# Epoch 16/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0224, Val Accuracy: 0.9890
# Epoch 17/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0212, Val Accuracy: 0.9890
# Epoch 18/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0211, Val Accuracy: 0.9890
# Epoch 19/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0211, Val Accuracy: 0.9906
# Epoch 20/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0212, Val Accuracy: 0.9906
# Epoch 21/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0213, Val Accuracy: 0.9906
# Epoch 22/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0212, Val Accuracy: 0.9922
# Epoch 23/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0215, Val Accuracy: 0.9906
# Epoch 24/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0218, Val Accuracy: 0.9906
# Epoch 25/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0217, Val Accuracy: 0.9922
# Epoch 26/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0215, Val Accuracy: 0.9922
# Epoch 27/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0217, Val Accuracy: 0.9922
# Epoch 28/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0216, Val Accuracy: 0.9922
# Epoch 29/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0216, Val Accuracy: 0.9922
# Epoch 30/30: Train Loss: 0.0000, Train Accuracy: 1.0000, Val Loss: 0.0228, Val Accuracy: 0.9922
# Fold 5 - Accuracy: 0.9922, Precision: 0.9922, Recall: 0.9922, F1 Score: 0.9922
#
# 5-Fold Cross-Validation Results:
# Average Accuracy: 0.9925
# Average Precision: 0.9926
# Average Recall: 0.9925
# Average F1 Score: 0.9925

# %%
model_path="/kaggle/working/B2vision.pth"
torch.save(model.state_dict(),model_path)
